# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
motion = np.load('data/processed_data/motion/lane1/2024-07-08.npy')

# %%
motion
# Out:
# array([[27.543222, 32.374207, 36.542244, ..., 31.679298, 35.17237 ,
#         30.763266],
#        [25.397749, 31.13897 , 34.780594, ..., 32.435383, 32.361614,
#         33.012955],
#        [21.93814 , 27.605354, 29.823599, ..., 32.422836, 30.658768,
#         32.25875 ],
#        ...,
#        [63.252254, 63.288204, 58.25104 , ..., 80.83957 , 79.81744 ,
#         82.39625 ],
#        [67.15176 , 61.72538 , 61.459064, ..., 82.93877 , 90.19702 ,
#         87.58543 ],
#        [63.89621 , 63.781666, 56.044655, ..., 85.96375 , 87.30461 ,
#         87.30389 ]], shape=(200, 3600), dtype=float32)

# %%
plt.figure(figsize=(10, 6))
plt.imshow(motion, cmap='gray', aspect='auto')

# %%
rds[51][mask]
# Out:
# array([68.      , 68.      , 62.      , 64.      , 59.      , 57.      ,
#        60.      , 44.      , 31.      , 11.      , 19.      , 33.      ,
#        42.      , 45.      , 47.      , 45.      , 52.      , 55.      ,
#        46.      , 49.      , 47.      , 51.      , 48.      , 50.      ,
#        40.      , 41.      , 28.      , 35.      , 35.      , 36.      ,
#        32.      , 23.      , 22.      , 20.      , 26.      , 40.      ,
#        43.      , 46.      , 50.      , 48.      , 45.      , 42.      ,
#        35.      , 28.      , 25.      , 31.      , 38.      , 38.      ,
#        42.      , 43.      , 49.      , 46.      , 48.      , 47.      ,
#        39.      , 25.      , 24.      , 16.      , 15.333333,  9.      ,
#        11.      , 11.      , 13.      , 26.      , 32.      , 28.      ,
#        26.      , 29.      , 28.      , 27.      , 23.      , 23.      ,
#        29.      , 31.      , 31.      , 31.      , 30.      , 31.      ,
# ...

# %%
plt.scatter(rds_values[51][600:1200], motion[51][600:1200], color='blue', alpha=0.5)
# show a line y=x
# plt.plot([0, 30], [0, 30], color='red', linestyle='--')
plt.xlabel('RDS')
plt.xlim(0, 30)
plt.ylim(0, 30)
plt.ylabel('MOTION')
# Out:
# Text(0, 0.5, 'MOTION')
